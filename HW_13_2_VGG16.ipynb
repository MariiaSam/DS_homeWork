# %% [markdown]
# # Частина 2
# ​
# В цій частині ми знову будемо працювати з датасетом fasion_mnist.
#
#
# На відміну від попереднього завдання вам пропонується створити згорткову нейромережу, що використовує VGG16 в якості згорткової основи.
#
#
#
# Навчіть отриману мережу на даних із датасету fasion_mnist. Спробуйте досягти максимально можливої точності класифікації за рахунок маніпуляції параметрами мережі. Під час навчання використовуйте прийоми донавчання та виділення ознак.
#
#
#
# Порівняйте точність отриманої згорткової мережі з точністю багатошарової мережі з попереднього завдання. Зробіть висновки.

# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf

from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from keras.models import Sequential
from keras.layers import BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.applications import VGG16
from tensorflow.keras.utils import to_categorical

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

x_train = np.expand_dims(x_train, axis=-1)
x_train = np.repeat(x_train, 3, axis=-1)
x_test= np.expand_dims(x_test, axis=-1)
x_test = np.repeat(x_test, 3, axis=-1)

x_train = tf.image.resize(x_train, [32, 32])
x_test = tf.image.resize(x_test, [32, 32])
x_train = x_train / 255.0
x_test = x_test / 255.0

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

print("x_train shape: ", x_train.shape)
print("x_test shape: ", x_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# x_train shape:  (60000, 32, 32, 3)
# x_test shape:  (10000, 32, 32, 3)

# %%
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(32, 32, 3))
for layer in base_model.layers:
    layer.trainable = False

model = Sequential([
    base_model,
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model.compile(
    loss="binary_crossentropy",
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=2e-5),
    metrics=["acc"]
)

history = model.fit(x_train, y_train, epochs=30, batch_size=130, validation_split=0.2, verbose=1)

test_loss, test_accuracy = model.evaluate(x_test, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# Epoch 1/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - acc: 0.7479 - loss: 0.1317 - val_acc: 0.7746 - val_loss: 0.1186
# Epoch 2/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - acc: 0.7526 - loss: 0.1288 - val_acc: 0.7768 - val_loss: 0.1172
# Epoch 3/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - acc: 0.7546 - loss: 0.1276 - val_acc: 0.7787 - val_loss: 0.1160
# Epoch 4/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - acc: 0.7555 - loss: 0.1272 - val_acc: 0.7807 - val_loss: 0.1148
# Epoch 5/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - acc: 0.7593 - loss: 0.1252 - val_acc: 0.7825 - val_loss: 0.1137
# Epoch 6/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - acc: 0.7614 - loss: 0.1240 - val_acc: 0.7842 - val_loss: 0.1127
# Epoch 7/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - acc: 0.7689 - loss: 0.1214 - val_acc: 0.7865 - val_loss: 0.1116
# Epoch 8/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - acc: 0.7652 - loss: 0.1214 - val_acc: 0.7877 - val_loss: 0.1106
# Epoch 9/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - acc: 0.7672 - loss: 0.1213 - val_acc: 0.7893 - val_loss: 0.1098
# Epoch 10/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - acc: 0.7657 - loss: 0.1205 - val_acc: 0.7904 - val_loss: 0.1089
# Epoch 11/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - acc: 0.7691 - loss: 0.1187 - val_acc: 0.7919 - val_loss: 0.1081
# Epoch 12/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - acc: 0.7753 - loss: 0.1179 - val_acc: 0.7928 - val_loss: 0.1073
# Epoch 13/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - acc: 0.7757 - loss: 0.1163 - val_acc: 0.7939 - val_loss: 0.1066
# Epoch 14/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - acc: 0.7768 - loss: 0.1155 - val_acc: 0.7943 - val_loss: 0.1058
# Epoch 15/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - acc: 0.7782 - loss: 0.1148 - val_acc: 0.7952 - val_loss: 0.1052
# Epoch 16/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - acc: 0.7788 - loss: 0.1145 - val_acc: 0.7971 - val_loss: 0.1045
# Epoch 17/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - acc: 0.7816 - loss: 0.1124 - val_acc: 0.7979 - val_loss: 0.1039
# Epoch 18/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - acc: 0.7837 - loss: 0.1122 - val_acc: 0.7977 - val_loss: 0.1033
# Epoch 19/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - acc: 0.7854 - loss: 0.1113 - val_acc: 0.7987 - val_loss: 0.1027
# Epoch 20/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - acc: 0.7871 - loss: 0.1111 - val_acc: 0.8002 - val_loss: 0.1021
# Epoch 21/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - acc: 0.7875 - loss: 0.1099 - val_acc: 0.8004 - val_loss: 0.1016
# Epoch 22/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - acc: 0.7862 - loss: 0.1097 - val_acc: 0.8013 - val_loss: 0.1011
# Epoch 23/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - acc: 0.7891 - loss: 0.1086 - val_acc: 0.8019 - val_loss: 0.1005
# Epoch 24/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - acc: 0.7916 - loss: 0.1081 - val_acc: 0.8026 - val_loss: 0.1001
# Epoch 25/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - acc: 0.7930 - loss: 0.1071 - val_acc: 0.8026 - val_loss: 0.0996
# Epoch 26/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - acc: 0.7941 - loss: 0.1065 - val_acc: 0.8024 - val_loss: 0.0992
# Epoch 27/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - acc: 0.7929 - loss: 0.1067 - val_acc: 0.8035 - val_loss: 0.0987
# Epoch 28/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - acc: 0.7933 - loss: 0.1069 - val_acc: 0.8043 - val_loss: 0.0982
# Epoch 29/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - acc: 0.7996 - loss: 0.1046 - val_acc: 0.8048 - val_loss: 0.0978
# Epoch 30/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - acc: 0.7947 - loss: 0.1045 - val_acc: 0.8054 - val_loss: 0.0974
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - acc: 0.8101 - loss: 0.0970
# Test Accuracy: 0.8061000108718872

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)                   │ (None, 1, 1, 512)           │      14,714,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,982,486 (57.15 MB)
#  Trainable params: 133,898 (523.04 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)
#  Optimizer params: 133,900 (523.05 KB)

# %%
accuracy = history.history['acc']
val_accuracy = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(accuracy) + 1)

plt.plot(epochs, accuracy, 'b', label="Training acc")
plt.plot(epochs, val_accuracy, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
from keras.optimizers import Adam

base_model = VGG16(weights='imagenet', include_top=False, input_shape=(32, 32, 3))
for layer in base_model.layers:
    layer.trainable = False

model = Sequential([
    base_model,
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

model.compile(
    loss="binary_crossentropy",
    optimizer=Adam(learning_rate=1e-4),
    metrics=["acc"]
)

history = model.fit(x_train, y_train, epochs=30, batch_size=130, validation_split=0.2, verbose=1)

test_loss, test_accuracy = model.evaluate(x_test, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# Epoch 1/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - acc: 0.2585 - loss: 0.3729 - val_acc: 0.7243 - val_loss: 0.1751
# Epoch 2/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - acc: 0.6519 - loss: 0.1833 - val_acc: 0.7563 - val_loss: 0.1372
# Epoch 3/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - acc: 0.7242 - loss: 0.1488 - val_acc: 0.7764 - val_loss: 0.1217
# Epoch 4/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - acc: 0.7501 - loss: 0.1332 - val_acc: 0.7874 - val_loss: 0.1124
# Epoch 5/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - acc: 0.7713 - loss: 0.1221 - val_acc: 0.7967 - val_loss: 0.1062
# Epoch 6/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - acc: 0.7827 - loss: 0.1154 - val_acc: 0.8039 - val_loss: 0.1015
# Epoch 7/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - acc: 0.7935 - loss: 0.1090 - val_acc: 0.8074 - val_loss: 0.0977
# Epoch 8/30
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step