# %% [markdown]
# <a href="https://colab.research.google.com/github/MariiaSam/DS_homeWork/blob/main/Hw2_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/My Drive/bestsellers with categories.csv'
df = pd.read_csv(file_path)
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
# Виведіть перші п'ять рядків (використовується функція head)
df.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
# Виведіть розміри датасету (використовуйте атрибут shape)
df.shape
# Out:
# (550, 7)

# %%
# Про скільки книг зберігає дані датасет?
count_books = df['Name'].value_counts()
count_books
# Out:
# Name
# Publication Manual of the American Psychological Association, 6th Edition       10
# StrengthsFinder 2.0                                                              9
# Oh, the Places You'll Go!                                                        8
# The Very Hungry Caterpillar                                                      7
# The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change     7
#                                                                                 ..
# Humans of New York : Stories                                                     1
# Howard Stern Comes Again                                                         1
# Homebody: A Guide to Creating Spaces You Never Want to Leave                     1
# Have a Little Faith: A True Story                                                1
# Night (Night)                                                                    1
# Name: count, Length: 351, dtype: int64

# %% [markdown]
# ***# Про скільки книг зберігає дані датасет?***

# %%
print('Відповідь: 351 книга')
# Out:
# Відповідь: 351 книга

# %% [markdown]
# **Для спрощення подальшої роботи давайте трохи підправимо назви змінних. Як бачите, тут усі назви починаються з великої літери, а одна - навіть містить пробіл. Це дуже небажано і може бути досить незручним. Давайте змінимо регістр на малий, а пробіл замінимо на нижнє підкреслення (snake_style). А заразом і вивчимо корисний атрибут датафрейму: columns (можна просто присвоїти список нових імен цьому атрибуту)
# df.columns = ['name', 'author', 'user_rating', 'reviews', 'price', 'year', 'genre']
#
# **

# %%
df.columns = ['name', 'author', 'user_rating', 'reviews', 'price', 'year', 'genre']
df.head()
# Out:
#                                                 name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      author  user_rating  reviews  price  year        genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %% [markdown]
# # **Первинне дослідження даних**

# %%
# Перевірте, чи у всіх рядків вистачає даних: виведіть кількість пропусків (na) у кожному зі стовпців (використовуйте функції isna та sum)
df.isna().sum()
# Out:
# name           0
# author         0
# user_rating    0
# reviews        0
# price          0
# year           0
# genre          0
# dtype: int64

# %% [markdown]
# ***Чи є в якихось змінних пропуски? (Так / ні)***

# %%
print("Відповідь: ні, пропусків немає")
# Out:
# Відповідь: ні, пропусків немає

# %% [markdown]
# **Перевірте, які є унікальні значення в колонці genre (використовуйте функцію unique)**

# %%
unique_genre = df['genre'].unique()
unique_genre
# Out:
# array(['Non Fiction', 'Fiction'], dtype=object)

# %% [markdown]
# ***Які є унікальні жанри?***

# %%
print("Відповідь: 'Non Fiction', 'Fiction'")
# Out:
# Відповідь: 'Non Fiction', 'Fiction'

# %% [markdown]
# **Тепер подивіться на розподіл цін: побудуйте діаграму (використовуйте kind='hist')**

# %%
price_df = df['price']
price_df
# Out:
# 0       8
# 1      22
# 2      15
# 3       6
# 4      12
#        ..
# 545     8
# 546     8
# 547     8
# 548     8
# 549     8
# Name: price, Length: 550, dtype: int64

# %%
price_df.plot(title="Розподіл цін", kind="hist")
# Out:
# <Axes: title={'center': 'Розподіл цін'}, ylabel='Frequency'>

# %% [markdown]
# ***Визначте, яка ціна у нас максимальна, мінімальна, середня, медіанна (використовуйте функції max, min, mean, median)***

# %%
print('Максимальна ціна:', price_df.max())
print('Максимальна ціна: ', price_df.min())
print('Середня ціна: ', price_df.mean())
print('Медіанна ціна: ', price_df.median())
# Out:
# Максимальна ціна: 105
# Максимальна ціна:  0
# Середня ціна:  13.1
# Медіанна ціна:  11.0

# %% [markdown]
# # Пошук та сортування даних

# %% [markdown]
# ***Який рейтинг у датасеті найвищий?***

# %%
rating_max = df['user_rating'].max()
rating_max
# Out:
# 4.9

# %%
print('Відповідь: 4.9')
# Out:
# Відповідь: 4.9

# %% [markdown]
# ***Скільки книг мають такий рейтинг?***

# %%
book_rating_max = df[df['user_rating'] == rating_max]['name'].unique().size
book_rating_max
# Out:
# 28

# %%
print('Відповідь: 28 книг мають такий рейтинг')
# Out:
# Відповідь: 28 книг мають такий рейтинг

# %% [markdown]
# ***Яка книга має найбільше відгуків?***

# %%
book_reviews = df.sort_values(by='reviews', ascending=False).head(1)
book_reviews['name'].values[0]
# Out:
# 'Where the Crawdads Sing'

# %%
print('Відповідь: "Where the Crawdads Sing" має найбільше відгуків')
# Out:
# Відповідь: "Where the Crawdads Sing" має найбільше відгуків

# %% [markdown]
# ***З тих книг, що потрапили до Топ-50 у 2015 році, яка книга найдорожча (можна використати проміжний датафрейм)?***

# %%
year_2015 = df[df['year'] == 2015].sort_values('user_rating', ascending=False)[:50]
year_2015
# Out:
#                                                   name  \
# 478                        The Very Hungry Caterpillar
# 248                          Oh, the Places You'll Go!
# 191  Jesus Calling: Enjoying Peace in His Presence ...
# 174                       Humans of New York : Stories
# 224                                   Love You Forever
# 123                               Giraffes Can't Dance
# 507                              To Kill a Mockingbird
# 447  The Pioneer Woman Cooks: Dinnertime - Comfort ...
# 437                           The Nightingale: A Novel
# 362                           The Day the Crayons Quit
# 352  The Boys in the Boat: Nine Americans and Their...
# 350                          The Book with No Pictures
# 325  The 5 Love Languages: The Secret to Love that ...
# 253              Old School (Diary of a Wimpy Kid #10)
# 542                                             Wonder
# 54   Creative Haven Creative Cats Coloring Book (Ad...
# ...

# %%
book_rating_max = year_2015.sort_values(by = 'price', ascending=False).iloc[0]["name"]
book_rating_max
# Out:
# 'Publication Manual of the American Psychological Association, 6th Edition'

# %%
# З тих книг, що потрапили до Топ-50 у 2015 році, яка книга найдорожча (можна використати проміжний датафрейм)

print('Відповідь: ', book_rating_max, 'найдорожча книга,  що потрапили до Топ-50 у 2015 році')
# Out:
# Відповідь:  Publication Manual of the American Psychological Association, 6th Edition найдорожча книга,  що потрапили до Топ-50 у 2015 році

# %% [markdown]
# ***Скільки книг жанру Fiction потрапили до Топ-50 у 2010 році (використовуйте &)?***

# %%
books_genre = df[(df['year'] == 2010) & (df['genre'] == 'Fiction')].sort_values('user_rating', ascending=False)[:50]
len(books_genre)
# Out:
# 20

# %%
# Скільки книг жанру Fiction потрапили до Топ-50 у 2010 році?
print("Відповідь: 20 книг жанру Fiction потрапили до Топ-50 у 2010 році")
# Out:
# Відповідь: 20 книг жанру Fiction потрапили до Топ-50 у 2010 році

# %% [markdown]
# ***Скільки книг з рейтингом 4.9 потрапило до рейтингу у 2010 та 2011 роках (використовуйте | або функцію isin)?***

# %%
books_rating_year = df[(df['year'] == 2010) | (df['year'] == 2011)]

books_rating = books_rating_year[books_rating_year['user_rating'] == 4.9]

# %%
len(books_rating)
# Out:
# 1

# %%
# Скільки книг з рейтингом 4.9 потрапило до рейтингу у 2010 та 2011 роках?

print("Відповідь: 1")
# Out:
# Відповідь: 1

# %% [markdown]
# *І насамкінець, давайте відсортуємо за зростанням ціни всіх книг, які потрапили до рейтингу в 2015 році і коштують дешевше за 8 доларів (використовуйте функцію sort_values).*

# %%
books_sort2015 = df[(df['year'] == 2015) & (df['price'] < 8)].sort_values(by=['price', 'user_rating'], ascending=True)
books_sort2015
# Out:
#                                                   name              author  \
# 507                              To Kill a Mockingbird          Harper Lee
# 206                         Knock-Knock Jokes for Kids         Rob Elliott
# 210                      Laugh-Out-Loud Jokes for Kids         Rob Elliott
# 111                                    First 100 Words        Roger Priddy
# 54   Creative Haven Creative Cats Coloring Book (Ad...     Marjorie Sarnat
# 123                               Giraffes Can't Dance       Giles Andreae
# 28                        Baby Touch and Feel: Animals                  DK
# 89   Dover Creative Haven Art Nouveau Animal Design...         Marty Noble
# 201  Killing Reagan: The Violent Assault That Chang...       Bill O'Reilly
# 55   Creative Haven Owls Coloring Book (Adult Color...     Marjorie Sarnat
# 63                      Dear Zoo: A Lift-the-Flap Book        Rod Campbell
# ...

# %% [markdown]
# ***Яка книга остання у відсортованому списку?***

# %%
print('Відповідь: "Old School (Diary of a Wimpy Kid #10)" ')
# Out:
# Відповідь: "Old School (Diary of a Wimpy Kid #10)"

# %% [markdown]
# # Агрегування даних та з'єднання таблиць

# %% [markdown]
# Для початку давайте подивимося на максимальну та мінімальну ціни для кожного з жанрів (використовуйте функції groupby та agg, для підрахунку мінімальних та максимальних значень використовуйте max та min). Не беріть усі стовпці, виберіть тільки потрібні вам

# %%
agr = df[["genre", "price"]].groupby("genre").agg(["min", "max"])
agr
# Out:
#             price
#               min  max
# genre
# Fiction         0   82
# Non Fiction     0  105

# %% [markdown]
# ***Максимальна ціна для жанру Fiction***

# %%
print("Відповідь: 82")
# Out:
# Відповідь: 82

# %% [markdown]
# ***Мінімальна ціна для жанру Fiction***

# %%
print("Відповідь: 0")
# Out:
# Відповідь: 0

# %% [markdown]
# ***Максимальна ціна для жанру Non Fiction***

# %%
print("Відповідь: 105")
# Out:
# Відповідь: 105

# %% [markdown]
# ***Мінімальна ціна для жанру Non Fiction***

# %%
print("Відповідь: 0")
# Out:
# Відповідь: 0

# %% [markdown]
# Тепер створіть новий датафрейм, який вміщатиме кількість книг для кожного з авторів (використовуйте функції groupby та agg, для підрахунку кількості використовуйте count). Не беріть усі стовпці, виберете тільки потрібні

# %%
new_df = df[['name', 'author']].groupby('author').agg('count')
new_df
# Out:
#                             name
# author
# Abraham Verghese               2
# Adam Gasiewski                 1
# Adam Mansbach                  1
# Adir Levy                      1
# Admiral William H. McRaven     1
# ...                          ...
# Walter Isaacson                3
# William Davis                  2
# William P. Young               2
# Wizards RPG Team               3
# Zhi Gang Sha                   2
#
# [248 rows x 1 columns]

# %% [markdown]
# ***Якої розмірності вийшла таблиця?***

# %%
print("Відповідь: 248")
# Out:
# Відповідь: 248

# %% [markdown]
# ***Який автор має найбільше книг?***

# %%
new_df.idxmax()
# Out:
# name    Jeff Kinney
# dtype: object

# %%
print('Відповідь: "Jeff Kinney"')
# Out:
# Відповідь: "Jeff Kinney"

# %% [markdown]
# ***Скільки книг цього автора?***

# %%
new_df.loc[new_df.idxmax()].iat[0,0]
# Out:
# 12

# %%
print('Відповідь: 12')
# Out:
# Відповідь: 12

# %% [markdown]
# **Тепер створіть другий датафрейм, який буде вміщати середній рейтинг для кожного автора (використовуйте функції groupby та agg, для підрахунку середнього значення використовуйте mean). Не беріть усі стовпці, виберете тільки потрібні**

# %%
new_df2 = df[['user_rating', 'author']].groupby('author').agg('mean')
new_df2
# Out:
#                             user_rating
# author
# Abraham Verghese               4.600000
# Adam Gasiewski                 4.400000
# Adam Mansbach                  4.800000
# Adir Levy                      4.800000
# Admiral William H. McRaven     4.700000
# ...                                 ...
# Walter Isaacson                4.566667
# William Davis                  4.400000
# William P. Young               4.600000
# Wizards RPG Team               4.800000
# Zhi Gang Sha                   4.600000
#
# [248 rows x 1 columns]

# %% [markdown]
# ***У якого автора середній рейтинг мінімальний?***

# %%
new_df2.loc[new_df2.idxmin()]
# Out:
#              user_rating
# author
# Donna Tartt          3.9

# %%
print('Відповідь: Donna Tartt')
# Out:
# Відповідь: Donna Tartt

# %% [markdown]
# ***Який у цього автора середній рейтинг?***

# %%
print('Відповідь: 3.9')
# Out:
# Відповідь: 3.9

# %% [markdown]
# **З'єднайте останні два датафрейми так, щоб для кожного автора було видно кількість книг та середній рейтинг (Використовуйте функцію concat з параметром axis=1). Збережіть результат у змінну**

# %%
df_concat = pd.concat([new_df, new_df2], axis=1)
df_concat.columns = ["count", "avg_rating"]
df_concat
# Out:
#                             count  avg_rating
# author
# Abraham Verghese                2    4.600000
# Adam Gasiewski                  1    4.400000
# Adam Mansbach                   1    4.800000
# Adir Levy                       1    4.800000
# Admiral William H. McRaven      1    4.700000
# ...                           ...         ...
# Walter Isaacson                 3    4.566667
# William Davis                   2    4.400000
# William P. Young                2    4.600000
# Wizards RPG Team                3    4.800000
# Zhi Gang Sha                    2    4.600000
#
# [248 rows x 2 columns]

# %% [markdown]
# **Відсортуйте датафрейм за зростаючою кількістю книг та зростаючим рейтингом (використовуйте функцію sort_values)**

# %%
df_concat.sort_values(['count', 'avg_rating'], ascending=True,  inplace=True)
df_concat
# Out:
#                                     count  avg_rating
# author
# Muriel Barbery                          1    4.000000
# Chris Cleave                            1    4.100000
# Ian K. Smith M.D.                       1    4.100000
# Pierre Dukan                            1    4.100000
# Elizabeth Strout                        1    4.200000
# ...                                   ...         ...
# American Psychological Association     10    4.500000
# Suzanne Collins                        11    4.663636
# Gary Chapman                           11    4.736364
# Rick Riordan                           11    4.772727
# Jeff Kinney                            12    4.800000
#
# [248 rows x 2 columns]

# %% [markdown]
# ***Який автор перший у списку?***

# %%
df_concat.index[0]
# Out:
# 'Muriel Barbery'

# %%
print('Відповідь: "Muriel Barbery"')
# Out:
# Відповідь: "Muriel Barbery"

# %% [markdown]
# # Візуалізація
# додайте від 3 до 5 графіків функцій різного типу на ваш вибір. Задайте графікам оформлення, щоб кожен графік у своїй домашній роботі чимось відрізнявся і не був схожим на інші. Можна використовувати як matplotlib, так і seaborn.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("darkgrid")
df
# Out:
#                                                   name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        author  user_rating  reviews  price  year        genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt


g = sns.FacetGrid(df, col="genre", height=4, aspect=1.5)
g.map(sns.lineplot, "year", "user_rating")
plt.show()

# %%
pivot_table = df.pivot_table(values='user_rating', index='year', columns='genre', aggfunc='mean')

sns.heatmap(pivot_table, annot=True, cmap='coolwarm')
plt.title('Середній рейтинг за роками та жанрами')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

sns.barplot(x='year', y='user_rating', hue='genre', data=df, palette='viridis')

plt.legend(title='Жанр', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.xlabel('Рік')
plt.ylabel('Середній рейтинг')
plt.title('Середній рейтинг фільмів за роками та жанрами')

plt.show()
